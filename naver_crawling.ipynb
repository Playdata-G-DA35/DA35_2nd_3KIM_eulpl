# %%
import pandas as pd
import numpy as np
import asyncio
import aiohttp
import os
from datetime import datetime, timedelta
import pymysql
import time
import re
import import_ipynb
from crawling_method import *


from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import nest_asyncio
# Out:
# importing Jupyter notebook from crawling_method.ipynb

# %%
#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# user_agent 지정
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'

#-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# URL 변수 지정 
start_date = '2024-03-25'
end_date = '2024-03-31'
loc = '연남'
category = '맛집'
page = 1

url_layout = make_search_url(start_date, end_date, loc, category, page)
print(url_layout, end = '\n\n') # url 확인차 print
# Out:
# https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=PERIOD&orderBy=sim&startDate=2024-03-25&endDate=2024-03-31&keyword=%23홍대%20%23맛집

# %%
# 페이지별로 블로그 제목과 URL 가져오기
titles_urls_list = get_blog_titles_and_urls(url_layout, start_date, end_date, loc, category, 30)

# %%
# print(page_res(titles_urls_list))

# %%
# Selenium 초기화
naver_driver = webdriver.Chrome()
print('open Chrome')

input_df = pd.DataFrame(columns = ['name', 'address'])

for titles, urls in titles_urls_list:
    print('.', end=' ')
    for i in range(len(titles)):
        extract_info_to_df(naver_driver, urls[i], input_df)
# Out:
# open Chrome
# . . . . . . . . . . . . . . error in https://blog.naver.com/emmapic/223395746848, no such element
# error in https://blog.naver.com/polycafe/223400043031, no such element
# error in https://blog.naver.com/polycafe/223399398574, no such element
# . . . . . error in https://blog.naver.com/kmm_review/223397816996, no such element
# . . . error in https://blog.naver.com/dbsduswl1/223397125773, no such element
# . . . . . . . .

# %%
display(input_df)
# Out:
#              name                         address
# 0         백스트리트피자            서울특별시 마포구 동교로 245 4층
# 1          모꼬지해산물          서울특별시 마포구 동교로27길 22 1층
# 2      김앤김대게 서교본점            서울특별시 마포구 양화로 100 3층
# 3          현우동 홍대       서울특별시 마포구 와우산로21길 28-8 1층
# 4            연남어부            서울특별시 마포구 동교로 220 1층
# ..            ...                             ...
# 200        룽쟝족발덮밥           서울특별시 마포구 홍익로2길 31 1층
# 201         오코메이드  서울특별시 마포구 와우산로29가길 86 1층 오코메이드
# 202        통통돼지뽈살   서울특별시 마포구 어울마당로 126-1 1층및 지하층
# 203          식스티즈          서울특별시 마포구 와우산로23길 9 1층
# 204  올바른스시 홍대역직영점    서울특별시 마포구 동교로 199-1 1층 올바른스시
#
# [205 rows x 2 columns]

# %%
out_df = make_count(input_df)
# Out:
# <string>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <string>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <string>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# <string>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
pd.set_option('display.max_rows', 70)
display(out_df)
# Out:
#            name                        address  count
# 0       백스트리트피자           서울특별시 마포구 동교로 245 4층      5
# 1        모꼬지해산물         서울특별시 마포구 동교로27길 22 1층      1
# 2    김앤김대게 서교본점           서울특별시 마포구 양화로 100 3층      1
# 3        현우동 홍대      서울특별시 마포구 와우산로21길 28-8 1층      2
# 4          연남어부           서울특별시 마포구 동교로 220 1층      2
# ..          ...                            ...    ...
# 134         스아게        서울특별시 마포구 와우산로29라길 7 1층      1
# 135          연교          서울특별시 마포구 연희로1길 65 1층      1
# 136         츠케루    서울특별시 마포구 와우산로23길 9 1층 102호      1
# 137      룽쟝족발덮밥          서울특별시 마포구 홍익로2길 31 1층      1
# 138      통통돼지뽈살  서울특별시 마포구 어울마당로 126-1 1층및 지하층      1
#
# [139 rows x 3 columns]

# %%
out_df.to_csv('march_week4_Yunnam.csv', encoding='cp949')
